# %%
import kalshi_python
import kalshi_client
from KalshiClientsBaseV2ApiKey import ExchangeClient
import time
import uuid

# %%
# coding: utf-8

"""
    Kalshi Trade API

    This documentation describes Kalshi's trading API (known as Trade API v2). By using this API, you agree to Kalshi's Developer Agreement (https://kalshi.com/developer-agreement).  # noqa: E501

    OpenAPI spec version: 2.0.0
    Contact: support@kalshi.com
    Generated by: https://github.com/swagger-api/swagger-codegen.git
"""

import pprint
import re  # noqa: F401

import six

class CreateOrderRequest(object):
    """NOTE: This class is auto generated by the swagger code generator program.

    Do not edit the class manually.
    """
    """
    Attributes:
      swagger_types (dict): The key is attribute name
                            and the value is attribute type.
      attribute_map (dict): The key is attribute name
                            and the value is json key in definition.
    """
    swagger_types = {
        'action': 'str',
        'buy_max_cost': 'int',
        'client_order_id': 'str',
        'count': 'int',
        'expiration_ts': 'int',
        'no_price': 'int',
        'sell_position_floor': 'int',
        'side': 'str',
        'ticker': 'str',
        'type': 'str',
        'yes_price': 'int'
    }

    attribute_map = {
        'action': 'action',
        'buy_max_cost': 'buy_max_cost',
        'client_order_id': 'client_order_id',
        'count': 'count',
        'expiration_ts': 'expiration_ts',
        'no_price': 'no_price',
        'sell_position_floor': 'sell_position_floor',
        'side': 'side',
        'ticker': 'ticker',
        'type': 'type',
        'yes_price': 'yes_price'
    }

    def __init__(self, action=None, buy_max_cost=None, client_order_id=None, count=None, expiration_ts=None, no_price=None, sell_position_floor=None, side=None, ticker=None, type=None, yes_price=None):  # noqa: E501
        """CreateOrderRequest - a model defined in Swagger"""  # noqa: E501
        self._action = None
        self._buy_max_cost = None
        self._client_order_id = None
        self._count = None
        self._expiration_ts = None
        self._no_price = None
        self._sell_position_floor = None
        self._side = None
        self._ticker = None
        self._type = None
        self._yes_price = None
        self.discriminator = None
        self.action = action
        if buy_max_cost is not None:
            self.buy_max_cost = buy_max_cost
        self.client_order_id = client_order_id
        self.count = count
        if expiration_ts is not None:
            self.expiration_ts = expiration_ts
        if no_price is not None:
            self.no_price = no_price
        if sell_position_floor is not None:
            self.sell_position_floor = sell_position_floor
        self.side = side
        self.ticker = ticker
        self.type = type
        if yes_price is not None:
            self.yes_price = yes_price

    @property
    def action(self):
        """Gets the action of this CreateOrderRequest.  # noqa: E501

        Specifies if this is a buy or sell order.  # noqa: E501

        :return: The action of this CreateOrderRequest.  # noqa: E501
        :rtype: str
        """
        return self._action

    @action.setter
    def action(self, action):
        """Sets the action of this CreateOrderRequest.

        Specifies if this is a buy or sell order.  # noqa: E501

        :param action: The action of this CreateOrderRequest.  # noqa: E501
        :type: str
        """
        if action is None:
            raise ValueError("Invalid value for `action`, must not be `None`")  # noqa: E501

        self._action = action

    @property
    def buy_max_cost(self):
        """Gets the buy_max_cost of this CreateOrderRequest.  # noqa: E501

        If type = market and action = buy, buy_max_cost represents the maximum cents that can be spent to acquire a position.  # noqa: E501

        :return: The buy_max_cost of this CreateOrderRequest.  # noqa: E501
        :rtype: int
        """
        return self._buy_max_cost

    @buy_max_cost.setter
    def buy_max_cost(self, buy_max_cost):
        """Sets the buy_max_cost of this CreateOrderRequest.

        If type = market and action = buy, buy_max_cost represents the maximum cents that can be spent to acquire a position.  # noqa: E501

        :param buy_max_cost: The buy_max_cost of this CreateOrderRequest.  # noqa: E501
        :type: int
        """

        self._buy_max_cost = buy_max_cost

    @property
    def client_order_id(self):
        """Gets the client_order_id of this CreateOrderRequest.  # noqa: E501

        Member-provided UUID to attach to the order.  # noqa: E501

        :return: The client_order_id of this CreateOrderRequest.  # noqa: E501
        :rtype: str
        """
        return self._client_order_id

    @client_order_id.setter
    def client_order_id(self, client_order_id):
        """Sets the client_order_id of this CreateOrderRequest.

        Member-provided UUID to attach to the order.  # noqa: E501

        :param client_order_id: The client_order_id of this CreateOrderRequest.  # noqa: E501
        :type: str
        """
        if client_order_id is None:
            raise ValueError("Invalid value for `client_order_id`, must not be `None`")  # noqa: E501

        self._client_order_id = client_order_id

    @property
    def count(self):
        """Gets the count of this CreateOrderRequest.  # noqa: E501

        Number of contracts to be bought or sold.  # noqa: E501

        :return: The count of this CreateOrderRequest.  # noqa: E501
        :rtype: int
        """
        return self._count

    @count.setter
    def count(self, count):
        """Sets the count of this CreateOrderRequest.

        Number of contracts to be bought or sold.  # noqa: E501

        :param count: The count of this CreateOrderRequest.  # noqa: E501
        :type: int
        """
        if count is None:
            raise ValueError("Invalid value for `count`, must not be `None`")  # noqa: E501

        self._count = count

    @property
    def expiration_ts(self):
        """Gets the expiration_ts of this CreateOrderRequest.  # noqa: E501

        Expiration time of the order, in unix seconds.  If this is not supplied, the order won't expire until explicitly cancelled. This is also known as Good 'Till Cancelled (GTC).  If the time is in the past, the order will attempt to partially or completely fill and the remaining unfilled quantity will be cancelled. This is also known as Immediate-or-Cancel (IOC).  If the time is in the future, the remaining unfilled quantity order will expire at the specified time.  # noqa: E501

        :return: The expiration_ts of this CreateOrderRequest.  # noqa: E501
        :rtype: int
        """
        return self._expiration_ts

    @expiration_ts.setter
    def expiration_ts(self, expiration_ts):
        """Sets the expiration_ts of this CreateOrderRequest.

        Expiration time of the order, in unix seconds.  If this is not supplied, the order won't expire until explicitly cancelled. This is also known as Good 'Till Cancelled (GTC).  If the time is in the past, the order will attempt to partially or completely fill and the remaining unfilled quantity will be cancelled. This is also known as Immediate-or-Cancel (IOC).  If the time is in the future, the remaining unfilled quantity order will expire at the specified time.  # noqa: E501

        :param expiration_ts: The expiration_ts of this CreateOrderRequest.  # noqa: E501
        :type: int
        """

        self._expiration_ts = expiration_ts

    @property
    def no_price(self):
        """Gets the no_price of this CreateOrderRequest.  # noqa: E501

        Submitting price of the No side of the trade, in cents. Exactly one of yes_price and no_price must be passed. If both prices are passed, return 400.  # noqa: E501

        :return: The no_price of this CreateOrderRequest.  # noqa: E501
        :rtype: int
        """
        return self._no_price

    @no_price.setter
    def no_price(self, no_price):
        """Sets the no_price of this CreateOrderRequest.

        Submitting price of the No side of the trade, in cents. Exactly one of yes_price and no_price must be passed. If both prices are passed, return 400.  # noqa: E501

        :param no_price: The no_price of this CreateOrderRequest.  # noqa: E501
        :type: int
        """

        self._no_price = no_price

    @property
    def sell_position_floor(self):
        """Gets the sell_position_floor of this CreateOrderRequest.  # noqa: E501

        SellPositionFloor will not let you flip position for a market order if set to 0.  # noqa: E501

        :return: The sell_position_floor of this CreateOrderRequest.  # noqa: E501
        :rtype: int
        """
        return self._sell_position_floor

    @sell_position_floor.setter
    def sell_position_floor(self, sell_position_floor):
        """Sets the sell_position_floor of this CreateOrderRequest.

        SellPositionFloor will not let you flip position for a market order if set to 0.  # noqa: E501

        :param sell_position_floor: The sell_position_floor of this CreateOrderRequest.  # noqa: E501
        :type: int
        """

        self._sell_position_floor = sell_position_floor

    @property
    def side(self):
        """Gets the side of this CreateOrderRequest.  # noqa: E501

        Specifies if this is a 'yes' or 'no' order.  # noqa: E501

        :return: The side of this CreateOrderRequest.  # noqa: E501
        :rtype: str
        """
        return self._side

    @side.setter
    def side(self, side):
        """Sets the side of this CreateOrderRequest.

        Specifies if this is a 'yes' or 'no' order.  # noqa: E501

        :param side: The side of this CreateOrderRequest.  # noqa: E501
        :type: str
        """
        if side is None:
            raise ValueError("Invalid value for `side`, must not be `None`")  # noqa: E501

        self._side = side

    @property
    def ticker(self):
        """Gets the ticker of this CreateOrderRequest.  # noqa: E501

        The ticker of the market the order will be placed in.  # noqa: E501

        :return: The ticker of this CreateOrderRequest.  # noqa: E501
        :rtype: str
        """
        return self._ticker

    @ticker.setter
    def ticker(self, ticker):
        """Sets the ticker of this CreateOrderRequest.

        The ticker of the market the order will be placed in.  # noqa: E501

        :param ticker: The ticker of this CreateOrderRequest.  # noqa: E501
        :type: str
        """
        if ticker is None:
            raise ValueError("Invalid value for `ticker`, must not be `None`")  # noqa: E501

        self._ticker = ticker

    @property
    def type(self):
        """Gets the type of this CreateOrderRequest.  # noqa: E501

        Specifies if this is a \"market\" or a \"limit\" order. Note that either the Yes Price or the No Price must be provided for limit orders.  # noqa: E501

        :return: The type of this CreateOrderRequest.  # noqa: E501
        :rtype: str
        """
        return self._type

    @type.setter
    def type(self, type):
        """Sets the type of this CreateOrderRequest.

        Specifies if this is a \"market\" or a \"limit\" order. Note that either the Yes Price or the No Price must be provided for limit orders.  # noqa: E501

        :param type: The type of this CreateOrderRequest.  # noqa: E501
        :type: str
        """
        if type is None:
            raise ValueError("Invalid value for `type`, must not be `None`")  # noqa: E501

        self._type = type

    @property
    def yes_price(self):
        """Gets the yes_price of this CreateOrderRequest.  # noqa: E501

        Submitting price of the Yes side of the trade, in cents. Exactly one of yes_price and no_price must be passed. If both prices are passed, return 400.  # noqa: E501

        :return: The yes_price of this CreateOrderRequest.  # noqa: E501
        :rtype: int
        """
        return self._yes_price

    @yes_price.setter
    def yes_price(self, yes_price):
        """Sets the yes_price of this CreateOrderRequest.

        Submitting price of the Yes side of the trade, in cents. Exactly one of yes_price and no_price must be passed. If both prices are passed, return 400.  # noqa: E501

        :param yes_price: The yes_price of this CreateOrderRequest.  # noqa: E501
        :type: int
        """

        self._yes_price = yes_price

    def to_dict(self):
        """Returns the model properties as a dict"""
        result = {}

        for attr, _ in six.iteritems(self.swagger_types):
            value = getattr(self, attr)
            if isinstance(value, list):
                result[attr] = list(map(
                    lambda x: x.to_dict() if hasattr(x, "to_dict") else x,
                    value
                ))
            elif hasattr(value, "to_dict"):
                result[attr] = value.to_dict()
            elif isinstance(value, dict):
                result[attr] = dict(map(
                    lambda item: (item[0], item[1].to_dict())
                    if hasattr(item[1], "to_dict") else item,
                    value.items()
                ))
            else:
                result[attr] = value
        if issubclass(CreateOrderRequest, dict):
            for key, value in self.items():
                result[key] = value

        return result

    def to_str(self):
        """Returns the string representation of the model"""
        return pprint.pformat(self.to_dict())

    def __repr__(self):
        """For `print` and `pprint`"""
        return self.to_str()

    def __eq__(self, other):
        """Returns true if both objects are equal"""
        if not isinstance(other, CreateOrderRequest):
            return False

        return self.__dict__ == other.__dict__

    def __ne__(self, other):
        """Returns true if both objects are not equal"""
        return not self == other

# %%
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.backends import default_backend

def load_private_key_from_file(private_key_path):
    with open(private_key_path, "rb") as key_file:
        private_key = serialization.load_pem_private_key(
            key_file.read(),
            password=None,  # or provide a password if your key is encrypted
            backend=default_backend()
        )
    return private_key

# %%
key_id = "039347d9-0f10-46a8-80ab-e353f31080a4"
    

#demo_key_id = "" # change these to be your personal credentials
#demo_private_key = load_private_key_from_file('kalshi-key.key')

# for prod
prod_api_base = "https://trading-api.kalshi.com/trade-api/v2"

# for demo
#demo_api_base = "https://demo-api.kalshi.co/trade-api/v2"
private_key_path = "C:\\Users\\19413\\Downloads\\Nemmo2k.txt"
## if wanting to test in prod:
exchange_client = ExchangeClient(exchange_api_base=prod_api_base, key_id = key_id, private_key=load_private_key_from_file(private_key_path))


# first we will check on the exchange status to confirm you are properly connected...
print(exchange_client.get_exchange_status())
# Out:
# {'exchange_active': True, 'exchange_estimated_resume_time': '2024-11-16T17:05:54.466253Z', 'trading_active': True}

# %%
from kalshi_client.client import KalshiClient
from kalshi_client.utils import load_private_key_from_file
import os

if __name__ == "__main__":
    key_id = "039347d9-0f10-46a8-80ab-e353f31080a4"
    
    # Specify the full path to 'Nemmo2k.txt'
    private_key_path = "C:\\Users\\19413\\Downloads\\Nemmo2k.txt"
    
    kalshi_client = KalshiClient(key_id=key_id, private_key=load_private_key_from_file(private_key_path))
    
    print(kalshi_client.get_balance())
# Out:
# {'balance': 7888}

# %%
eventTicker = 'KXRTMUFASA'
eventResponse = kalshi_client.get_event(eventTicker)
print(eventResponse)
# Out:
# {'event': {'event_ticker': 'KXRTMUFASA', 'series_ticker': 'KXRTMUFASA', 'sub_title': 'On Monday following wide release', 'title': '"Mufasa" Rotten Tomatoes score?', 'collateral_return_type': '', 'mutually_exclusive': False, 'category': 'Entertainment'}, 'markets': [{'ticker': 'KXRTMUFASA-45', 'event_ticker': 'KXRTMUFASA', 'market_type': 'binary', 'title': '', 'subtitle': 'Above 45::', 'yes_sub_title': 'Above 45', 'no_sub_title': 'Above 45', 'open_time': '2024-11-22T15:00:00Z', 'close_time': '2024-12-23T15:00:00Z', 'expected_expiration_time': '2024-12-23T15:00:00Z', 'expiration_time': '2024-12-30T15:00:00Z', 'latest_expiration_time': '2024-12-30T15:00:00Z', 'settlement_timer_seconds': 3598, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 97, 'yes_ask': 99, 'no_bid': 1, 'no_ask': 3, 'last_price': 98, 'previous_yes_bid': 0, 'previous_yes_ask': 0, 'previous_price': 0, 'volume': 103489, 'volume_24h': 65335, 'liquidity': 5217567, 'open_interest': 60611, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'greater', 'floor_strike': 45, 'rules_primary': 'If Mufasa has a Tomatometer score of above 45 on Dec 23, 2024 at 10:00AM ET, then the market resolves to Yes.', 'rules_secondary': 'The "Fresh!" and "Certified Fresh!" subtitles are meant for illustrative purposes only.'}, {'ticker': 'KXRTMUFASA-50', 'event_ticker': 'KXRTMUFASA', 'market_type': 'binary', 'title': '', 'subtitle': 'Above 50', 'yes_sub_title': 'Above 50', 'no_sub_title': 'Above 50', 'open_time': '2024-11-30T21:30:53Z', 'close_time': '2024-12-23T15:00:00Z', 'expected_expiration_time': '2024-12-23T15:00:00Z', 'expiration_time': '2024-12-30T15:00:00Z', 'latest_expiration_time': '2024-12-30T15:00:00Z', 'settlement_timer_seconds': 3598, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 88, 'yes_ask': 89, 'no_bid': 11, 'no_ask': 12, 'last_price': 89, 'previous_yes_bid': 0, 'previous_yes_ask': 0, 'previous_price': 0, 'volume': 116162, 'volume_24h': 70646, 'liquidity': 3561987, 'open_interest': 68630, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'greater', 'floor_strike': 50, 'rules_primary': 'If Mufasa has a Tomatometer score of above 50 on Dec 23, 2024 at 10:00AM ET, then the market resolves to Yes.', 'rules_secondary': 'The "Fresh!" and "Certified Fresh!" subtitles are meant for illustrative purposes only.'}, {'ticker': 'KXRTMUFASA-55', 'event_ticker': 'KXRTMUFASA', 'market_type': 'binary', 'title': '', 'subtitle': 'Above 55', 'yes_sub_title': 'Above 55', 'no_sub_title': 'Above 55', 'open_time': '2024-11-30T21:30:00Z', 'close_time': '2024-12-23T15:00:00Z', 'expected_expiration_time': '2024-12-23T15:00:00Z', 'expiration_time': '2024-12-30T15:00:00Z', 'latest_expiration_time': '2024-12-30T15:00:00Z', 'settlement_timer_seconds': 3598, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 63, 'yes_ask': 64, 'no_bid': 36, 'no_ask': 37, 'last_price': 64, 'previous_yes_bid': 0, 'previous_yes_ask': 0, 'previous_price': 0, 'volume': 167311, 'volume_24h': 116505, 'liquidity': 9079536, 'open_interest': 84871, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'greater', 'floor_strike': 55, 'rules_primary': 'If Mufasa has a Tomatometer score of above 55 on Dec 23, 2024 at 10:00AM ET, then the market resolves to Yes.', 'rules_secondary': 'The "Fresh!" and "Certified Fresh!" subtitles are meant for illustrative purposes only.'}, {'ticker': 'KXRTMUFASA-60', 'event_ticker': 'KXRTMUFASA', 'market_type': 'binary', 'title': '', 'subtitle': 'Above 60:: This movie is "Fresh!"', 'yes_sub_title': 'Above 60', 'no_sub_title': 'Above 60', 'open_time': '2024-11-22T15:00:00Z', 'close_time': '2024-12-23T15:00:00Z', 'expected_expiration_time': ...

# %%
marketTicker = 'KXRTMUFASA-50'
marketResponse = kalshi_client.get_market(marketTicker)
print('\nMarket: ' + marketTicker)
print(marketResponse)
# Out:
# Market: KXRTMUFASA-50
# {'market': {'ticker': 'KXRTMUFASA-50', 'event_ticker': 'KXRTMUFASA', 'market_type': 'binary', 'title': 'Mufasa Rotten Tomatoes score?', 'subtitle': 'Above 50', 'yes_sub_title': 'Above 50', 'no_sub_title': 'Above 50', 'open_time': '2024-11-30T21:30:53Z', 'close_time': '2024-12-23T15:00:00Z', 'expected_expiration_time': '2024-12-23T15:00:00Z', 'expiration_time': '2024-12-30T15:00:00Z', 'latest_expiration_time': '2024-12-30T15:00:00Z', 'settlement_timer_seconds': 3598, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 88, 'yes_ask': 90, 'no_bid': 10, 'no_ask': 12, 'last_price': 89, 'previous_yes_bid': 90, 'previous_yes_ask': 96, 'previous_price': 89, 'volume': 116301, 'volume_24h': 70785, 'liquidity': 3616916, 'open_interest': 68630, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': 'Entertainment', 'risk_limit_cents': 0, 'strike_type': 'greater', 'floor_strike': 50, 'rules_primary': 'If Mufasa has a Tomatometer score of above 50 on Dec 23, 2024 at 10:00AM ET, then the market resolves to Yes.', 'rules_secondary': 'The "Fresh!" and "Certified Fresh!" subtitles are meant for illustrative purposes only.'}}

# %%
orderUuid = str(uuid.uuid4())


orderResponse = kalshi_client.create_order(
    client_order_id=orderUuid,
    side="yes",
    action='buy',
    count=10,
    type='market',
    ticker=marketTicker,
)

print('\nOrder submitted: ')
print(orderResponse)
# Out:
# Order submitted:
# {'order': {'order_id': '94c10a6f-f5f4-4d59-a1ac-0e3174b9a404', 'user_id': '2b01c238-0481-48d9-acc4-9d5c01c025d4', 'ticker': 'KXRTMUFASA-50', 'status': 'executed', 'yes_price': 99, 'no_price': 1, 'created_time': '2024-12-17T21:03:45.387421Z', 'expiration_time': None, 'self_trade_prevention_type': '', 'action': 'buy', 'side': 'yes', 'type': 'market', 'client_order_id': 'a2386656-b41b-479c-9cbe-385485cc205b', 'order_group_id': ''}}

# %%
orderUuid = str(uuid.uuid4())


orderResponse = kalshi_client.create_order(
    client_order_id=orderUuid,
    side="yes",
    action='sell',
    count=10,
    type='market',
    ticker=marketTicker,
)

print('\nOrder submitted: ')
print(orderResponse)
# Out:
# Order submitted:
# {'order': {'order_id': '8f001cac-f057-4ee9-85b4-06e50eb1713f', 'user_id': '2b01c238-0481-48d9-acc4-9d5c01c025d4', 'ticker': 'KXRTMUFASA-50', 'status': 'executed', 'yes_price': 1, 'no_price': 99, 'created_time': '2024-12-17T21:04:12.530138Z', 'expiration_time': '2024-12-17T20:04:12.52862Z', 'self_trade_prevention_type': '', 'action': 'sell', 'side': 'yes', 'type': 'market', 'client_order_id': '52c3483f-7c1c-4843-a139-96e9ae057fad', 'order_group_id': ''}}

# %%
# What are cursors and how do they work?
    
# The Cursor represents a pointer to the next page of records in the pagination.
# So this optional parameter, when filled, should be filled with the cursor string returned in a previous request to this end-point.
# Filling this would basically tell the api to get the next page containing the number of records passed on the limit parameter.
# On the other side not filling it tells the api you want to get the first page for another query.
# The cursor does not store any filters, so if any filter parameters like tickers, max_ts or min_ts were passed in the original query they must be passed again.

# Let's try it in action! Suppose we wanted to get the next 100 market objects...




markets_response = exchange_client.get_markets(**market_params)
cursor = markets_response['cursor']
market_params = {'limit':100,
                    'cursor':cursor, # passing in the cursor from the previous get_markets call
                    'event_ticker': None,
                    'series_ticker': None,
                    'max_close_ts': None, # pass in unix_ts
                    'min_close_ts': None, # pass in unix_ts
                    'status': None,
                    'tickers':None}

print('keys:', markets_response.keys())
print()
print('number of objects:', len(markets_response['markets'])) # 100 objects!
print()
print('first market in market_response payload:', markets_response['markets'][0]) # new markets!
print()
print('new cursor!', cursor)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[62], line 14
#       1 # What are cursors and how do they work?
#       2
#       3 # The Cursor represents a pointer to the next page of records in the pagination.
#    (...)
#       8
#       9 # Let's try it in action! Suppose we wanted to get the next 100 market objects...
# ---> 14 markets_response = exchange_client.get_markets(**market_params)
#      15 cursor = markets_response['cursor']
#      16 market_params = {'limit':100,
#      17                     'cursor':cursor, # passing in the cursor from the previous get_markets call
#      18                     'event_ticker': None,
#    (...)
#      22                     'status': None,
#      23                     'tickers':None}
#
# File c:\Users\19413\.vscode\Python-Work\Rotten-Tomatoes\myenv\KalshiClientsBaseV2ApiKey.py:190, in ExchangeClient.get_markets(self, limit, cursor, event_ticker, series_ticker, max_close_ts, min_close_ts, status, tickers)
#     179 def get_markets(self,
#     180                     limit:Optional[int]=None,
#     181                     cursor:Optional[str]=None,
#    (...)
#     187                     tickers:Optional[str]=None,
#     188                         ):
#     189     query_string = self.query_generation(params={k: v for k,v in locals().items()})
# --> 190     dictr = self.get(self.markets_url+query_string)
#     191     return dictr
#
# File c:\Users\19413\.vscode\Python-Work\Rotten-Tomatoes\myenv\KalshiClientsBaseV2ApiKey.py:72, in KalshiClient.get(self, path, params)
#      67 self.rate_limit()
#      69 response = requests.get(
#      70     self.host + path, headers=self.request_headers("GET", path), params=params
#      71 )
# ---> 72 self.raise_if_bad_response(response)
#      73 return response.json()
#
# File c:\Users\19413\.vscode\Python-Work\Rotten-Tomatoes\myenv\KalshiClientsBaseV2ApiKey.py:131, in KalshiClient.raise_if_bad_response(self, response)
#     129 def raise_if_bad_response(self, response: requests.Response) -> None:
#     130     if response.status_code not in range(200, 299):
# --> 131         raise HttpError(response.reason, response.status_code)
#
# HttpError: HttpError(401 Unauthorized)

# %%
# Next, let's look at event level data by passing an event ticker to the get_event endpoint...

event_ticker = markets_response['markets'][5]['event_ticker']
event_params = {'event_ticker': event_ticker}
event_response = exchange_client.get_event(**event_params)

print('keys:', event_response.keys())
print()
print('event object:', event_response['event'])
print()
print('first market in event_response payload:', event_response['markets'][0])
# Out:
# keys: dict_keys(['event', 'markets'])
#
# event object: {'event_ticker': 'GBPUSDH-24AUG2817', 'series_ticker': 'GBPUSDH', 'sub_title': 'Aug 28, 2024 at 5pm EDT', 'title': 'GBP/USD price today at 5pm EDT?', 'mutually_exclusive': False, 'category': 'Financials', 'strike_date': '2024-08-28T21:00:00Z'}
#
# first market in event_response payload: {'ticker': 'GBPUSDH-24AUG2817-T1.29899', 'event_ticker': 'GBPUSDH-24AUG2817', 'market_type': 'binary', 'title': '', 'subtitle': '1.29900 or above', 'yes_sub_title': '1.29900 or above', 'no_sub_title': '1.29900 or above', 'open_time': '2024-08-28T13:03:01Z', 'close_time': '2024-08-28T21:00:00Z', 'expected_expiration_time': '2024-08-28T21:00:00Z', 'expiration_time': '2024-09-04T21:00:00Z', 'latest_expiration_time': '2024-09-04T21:00:00Z', 'settlement_timer_seconds': 3600, 'status': 'active', 'response_price_units': 'usd_cent', 'notional_value': 100, 'tick_size': 1, 'yes_bid': 0, 'yes_ask': 0, 'no_bid': 100, 'no_ask': 100, 'last_price': 0, 'previous_yes_bid': 0, 'previous_yes_ask': 0, 'previous_price': 0, 'volume': 0, 'volume_24h': 0, 'liquidity': 0, 'open_interest': 0, 'result': '', 'can_close_early': True, 'expiration_value': '', 'category': '', 'risk_limit_cents': 0, 'strike_type': 'greater', 'floor_strike': 1.29899, 'rules_primary': 'If the price of the Pound Sterling/US Dollar for August 28, 2024 at 5 PM EDT is above 1.29899, then the market resolves to Yes.', 'rules_secondary': ''}

# %%
# Next, let's look at series level data by passing a series ticker to the get_series endpoint! 
series_ticker = event_response['event']['series_ticker']
series_params = {'series_ticker': series_ticker}
series_response = exchange_client.get_series(**series_params)

print('keys:', series_response.keys())
print()
print('series object:', series_response['series'])
print()
# Out:
# keys: dict_keys(['series'])
#
# series object: {'ticker': 'GBPUSDH', 'frequency': 'hourly', 'title': 'GBP/USD over/under', 'category': 'Financials', 'tags': [], 'settlement_sources': [{'url': 'https://www.tradingview.com/chart/?symbol=FX_IDC%3AGBPUSD', 'name': 'ICE'}], 'contract_url': 'https://kalshi-public-docs.s3.us-east-1.amazonaws.com/regulatory/product-certifications/GBPUSD.pdf'}

# %%
# Next let's look at the recent market history for a market
ticker = 'NXRTMUFASA'

market_history_params = {'ticker': ticker,
                            'limit': 100,
                            'cursor': None,
                            'max_ts': None, # pass in unix_ts
                            'min_ts': round(time.time()-1000000) # passing a recent unix_ts
                                }
market_history_response = exchange_client.get_market_history(**market_history_params)

print('keys:', market_history_response.keys())
print()
print('most recent market history object:', market_history_response['history'][-1])
print()

# and then also look at the most current view of the orderbook
market_history_params = {'ticker':ticker,
                            'depth': 30
                                }
orderbook_response = exchange_client.get_orderbook(**market_history_params)

print('keys:', orderbook_response.keys())
print()
print('orderbook object:', orderbook_response)
print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 8
#       1 # Next let's look at the recent market history for a market
#       2 ticker = 'NXRTMUFASA'
#       4 market_history_params = {'ticker': ticker,
#       5                             'limit': 100,
#       6                             'cursor': None,
#       7                             'max_ts': None, # pass in unix_ts
# ----> 8                             'min_ts': round(time.time()-1000000) # passing a recent unix_ts
#       9                                 }
#      10 market_history_response = exchange_client.get_market_history(**market_history_params)
#      12 print('keys:', market_history_response.keys())
#
# NameError: name 'time' is not defined

# %%
# Now let's suppose we wanted to place a trade on one of these markets... 
# to do so, we would first want to check out available balance...

current_balance = exchange_client.get_balance()
current_balance
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[56], line 4
#       1 # Now let's suppose we wanted to place a trade on one of these markets...
#       2 # to do so, we would first want to check out available balance...
# ----> 4 current_balance = exchange_client.get_balance()
#       5 current_balance
#
# File c:\Users\19413\.vscode\Python-Work\Rotten-Tomatoes\myenv\KalshiClientsBaseV2ApiKey.py:258, in ExchangeClient.get_balance(self)
#     257 def get_balance(self,):
# --> 258     dictr = self.get(self.portfolio_url+'/balance')
#     259     return dictr
#
# File c:\Users\19413\.vscode\Python-Work\Rotten-Tomatoes\myenv\KalshiClientsBaseV2ApiKey.py:72, in KalshiClient.get(self, path, params)
#      67 self.rate_limit()
#      69 response = requests.get(
#      70     self.host + path, headers=self.request_headers("GET", path), params=params
#      71 )
# ---> 72 self.raise_if_bad_response(response)
#      73 return response.json()
#
# File c:\Users\19413\.vscode\Python-Work\Rotten-Tomatoes\myenv\KalshiClientsBaseV2ApiKey.py:131, in KalshiClient.raise_if_bad_response(self, response)
#     129 def raise_if_bad_response(self, response: requests.Response) -> None:
#     130     if response.status_code not in range(200, 299):
# --> 131         raise HttpError(response.reason, response.status_code)
#
# HttpError: HttpError(401 Unauthorized)

# %%
# Now that you have some balance, you might want to see how your current positions are doing...

positions_params = {'limit': None,
                        'cursor': None,
                        'settlement_status': None,
                        'ticker': None,
                        'event_ticker': None}

current_position = exchange_client.get_positions(**positions_params)
current_position
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[57], line 9
#       1 # Now that you have some balance, you might want to see how your current positions are doing...
#       3 positions_params = {'limit': None,
#       4                         'cursor': None,
#       5                         'settlement_status': None,
#       6                         'ticker': None,
#       7                         'event_ticker': None}
# ----> 9 current_position = exchange_client.get_positions(**positions_params)
#      10 current_position
#
# File c:\Users\19413\.vscode\Python-Work\Rotten-Tomatoes\myenv\KalshiClientsBaseV2ApiKey.py:355, in ExchangeClient.get_positions(self, limit, cursor, settlement_status, ticker, event_ticker)
#     353 positions_url = self.portfolio_url + '/positions'
#     354 query_string = self.query_generation(params={k: v for k,v in locals().items()})
# --> 355 dictr = self.get(positions_url + query_string)
#     356 return dictr
#
# File c:\Users\19413\.vscode\Python-Work\Rotten-Tomatoes\myenv\KalshiClientsBaseV2ApiKey.py:72, in KalshiClient.get(self, path, params)
#      67 self.rate_limit()
#      69 response = requests.get(
#      70     self.host + path, headers=self.request_headers("GET", path), params=params
#      71 )
# ---> 72 self.raise_if_bad_response(response)
#      73 return response.json()
#
# File c:\Users\19413\.vscode\Python-Work\Rotten-Tomatoes\myenv\KalshiClientsBaseV2ApiKey.py:131, in KalshiClient.raise_if_bad_response(self, response)
#     129 def raise_if_bad_response(self, response: requests.Response) -> None:
#     130     if response.status_code not in range(200, 299):
# --> 131         raise HttpError(response.reason, response.status_code)
#
# HttpError: HttpError(401 Unauthorized)

# %%
# seems like some of your recent orders had been filled. To check on those we use the get_positions endpoint ...

fills_params = {'ticker':None,
                    'order_id':None,
                    'min_ts':None,
                    'max_ts':None,
                    'limit': None,
                    'cursor': None}

fills = exchange_client.get_fills(**fills_params)
fills
# Out:
# {'fills': [{'trade_id': '2a68e347-325f-4801-af09-516bbcd17fb3',
#    'ticker': 'BTCMAXY-24DEC31-80000',
#    'order_id': '149b060c-e263-4e6f-9a7b-97fd468f3900',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 100,
#    'yes_price': 62,
#    'no_price': 38,
#    'is_taker': False,
#    'created_time': '2024-07-31T20:13:10.833106Z'},
#   {'trade_id': '0801aca3-6230-4093-a699-a6b22908bd97',
#    'ticker': 'BTCMAXY-24DEC31-80000',
#    'order_id': 'f5d8a8a6-b9ab-46b9-a6d6-88a1b7b16798',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 50,
#    'yes_price': 65,
#    'no_price': 35,
#    'is_taker': True,
#    'created_time': '2024-07-31T17:34:34.116259Z'},
#   {'trade_id': '63f3afbd-b82d-4526-8ae3-4d08c6933329',
#    'ticker': 'LLM1-24DEC31-A',
#    'order_id': '47dc838c-6501-4358-856c-dddd7b1f3d82',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 50,
#    'yes_price': 39,
#    'no_price': 61,
#    'is_taker': True,
#    'created_time': '2024-07-29T15:07:29.283082Z'},
#   {'trade_id': 'f95a179c-7a91-4645-bc47-6ec3f40a848b',
#    'ticker': 'CPICORE-24JUN-T0.1',
#    'order_id': '0460ee64-f6b6-4fe3-9272-f00d315ab552',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 100,
#    'yes_price': 57,
#    'no_price': 43,
#    'is_taker': True,
#    'created_time': '2024-06-25T18:05:36.856041Z'},
#   {'trade_id': 'eb6cdd01-717a-4d63-a0e5-493f46e33971',
#    'ticker': 'ACPI-24-B3.5',
#    'order_id': 'dc105b49-32e0-439d-9e30-ffbe5f2f30f3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 100,
#    'yes_price': 51,
#    'no_price': 49,
#    'is_taker': True,
#    'created_time': '2024-06-21T15:04:57.063233Z'},
#   {'trade_id': '639750b1-bca9-437c-b2d0-5d2474083b99',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.771596Z'},
#   {'trade_id': 'a6ad9562-5281-4c96-b100-a37d6f3def88',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.761949Z'},
#   {'trade_id': 'd2e240b7-11f9-4f85-8d1e-743d82e3a4ce',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.751534Z'},
#   {'trade_id': '99572208-ff64-409a-8151-24a6a25d115f',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.740622Z'},
#   {'trade_id': '2903c8e6-a907-4860-aa31-69e009373a44',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.732118Z'},
#   {'trade_id': '8b577970-da71-45f0-81a6-e0bd8ee4bed4',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.722105Z'},
#   {'trade_id': '6f3be3e5-21c6-424d-a59f-88ed62f9dfec',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.711114Z'},
#   {'trade_id': 'e630a35a-ece2-4d9f-b273-b1f7efd69f0c',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.701864Z'},
#   {'trade_id': '1240d1ac-0028-43db-ae15-7fb47146a7ff',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.691349Z'},
#   {'trade_id': '349b6d2e-c519-4ea4-b99a-0efe774954ff',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.681591Z'},
#   {'trade_id': '1fdfca3f-66b7-418a-8649-ad7c5951a670',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': '29a88cc4-16cb-4eba-a3e3-7bde8723bad3',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 56,
#    'no_price': 44,
#    'is_taker': False,
#    'created_time': '2024-06-20T22:39:35.673959Z'},
#   {'trade_id': 'b5b3b84d-9b3e-4c94-a794-1011ba793050',
#    'ticker': 'LLM1-24DEC31-OAI',
#    'order_id': 'b6ef1ef0-dc6e-4a71-b1de-81b78c7a9335',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 10,
#    'yes_price': 59,
#    'no_price': 41,
#    'is_taker': True,
#    'created_time': '2024-06-20T21:20:07.472512Z'},
#   {'trade_id': '86c75ee0-9e11-4830-b052-c274c23f103b',
#    'ticker': 'ACPICORE-24-B3.5',
#    'order_id': 'beb29043-8e55-4f12-8c6a-3c73531b80c4',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 100,
#    'yes_price': 63,
#    'no_price': 37,
#    'is_taker': True,
#    'created_time': '2024-06-18T21:35:18.921885Z'},
#   {'trade_id': 'aea01105-856f-413a-bc19-22d6f143076b',
#    'ticker': 'BTCMAXY-24DEC31-90000',
#    'order_id': 'e288726d-885f-4fd3-bcb5-230efdd1fc3f',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 100,
#    'yes_price': 51,
#    'no_price': 49,
#    'is_taker': True,
#    'created_time': '2024-06-03T18:04:41.052476Z'},
#   {'trade_id': '866bd45a-26cd-4a5a-8565-709413749224',
#    'ticker': 'CREDITCDEF-24-Q1-3.10',
#    'order_id': '6b1d2a7e-024c-4b64-9e26-f4e00649a91d',
#    'side': 'yes',
#    'action': 'buy',
#    'count': 10,
#    'yes_price': 93,
#    'no_price': 7,
#    'is_taker': True,
#    'created_time': '2024-05-02T19:12:44.449499Z'},
#   {'trade_id': '5e75bddc-d348-4108-a6f5-cce9849fb1ac',
#    'ticker': 'NASDAQ100Y-24DEC31-B13750',
#    'order_id': '8edb4350-7d5d-4c7e-a1e3-f0cc86a73658',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 99,
#    'no_price': 1,
#    'is_taker': True,
#    'created_time': '2024-05-02T19:12:20.488391Z'},
#   {'trade_id': '491bf593-368b-44d3-93e4-e9ca3856c5e9',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 318,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-05-01T03:30:39.898419Z'},
#   {'trade_id': '587b8804-cf08-429c-9cd2-33ff9381271d',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.669585Z'},
#   {'trade_id': '44d3fed4-c80a-4e46-be15-9b64de44c792',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.660427Z'},
#   {'trade_id': 'ac704293-f804-4766-8691-9069bcf2019e',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.654989Z'},
#   {'trade_id': 'c97ce740-0945-425c-b8f0-e534da1acae6',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.649737Z'},
#   {'trade_id': '191ac1fc-a414-48fa-88ab-67e02937c440',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.64467Z'},
#   {'trade_id': 'a99530a4-c4a8-4966-8fbe-e5e31899f7d8',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.632737Z'},
#   {'trade_id': '4010fa85-b5f8-4f34-a7fa-6f62bc54db5f',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.624691Z'},
#   {'trade_id': '96839e37-4813-4b68-a409-eb8117235268',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.613766Z'},
#   {'trade_id': '0e42eac5-8181-4ae7-95f4-3839c25e556c',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-29T14:03:22.60067Z'},
#   {'trade_id': 'c477f012-daac-46f9-9579-2eeeef44c3a7',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.579292Z'},
#   {'trade_id': 'f8eb6143-6d87-43b0-9517-98e32c9cd968',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.567761Z'},
#   {'trade_id': '2e80bab6-aaf7-452d-b74f-776d1ef32ea8',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.560543Z'},
#   {'trade_id': 'b96aedc0-406c-472b-a9e7-e606cff73d58',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.549788Z'},
#   {'trade_id': '0e2daea7-f3ba-4a12-8d7b-ccda45ec51b6',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.538126Z'},
#   {'trade_id': 'cf0751b6-4d74-452b-add4-06e81b658c0b',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.528525Z'},
#   {'trade_id': 'f6f67603-a449-489d-a3b3-7e50571df080',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.517946Z'},
#   {'trade_id': 'd7c878f7-195f-405d-a3ba-e76c8ce8a1e5',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.509665Z'},
#   {'trade_id': '278aea42-0522-4727-9056-ebcac491807d',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.499476Z'},
#   {'trade_id': '7f9254aa-c700-49a8-a3de-c89128eed843',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.487964Z'},
#   {'trade_id': '06e5af39-bda5-4e4c-9bf5-776f8ab4a527',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.472907Z'},
#   {'trade_id': 'd3924973-6db9-4aed-96c0-a66f91308c26',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-26T00:11:34.466669Z'},
#   {'trade_id': 'f823000f-be7f-430b-9a49-0d8d32ccc571',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.759736Z'},
#   {'trade_id': '05237fa8-149f-457d-bb50-3e695d6c3e5e',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.747567Z'},
#   {'trade_id': '37e659a4-7fe9-4021-aa31-93638ab46f93',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.741255Z'},
#   {'trade_id': '73f6ecf3-58fc-4ee3-b1b1-c4ab9e9ed837',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.728575Z'},
#   {'trade_id': '9b9a8da3-6f6a-4410-aab7-3080754e33e9',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.721987Z'},
#   {'trade_id': '35572b00-793f-44d2-923a-5210438a3505',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.709179Z'},
#   {'trade_id': 'a8e1b393-8afa-4694-978d-e094ac9aadb1',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.700756Z'},
#   {'trade_id': 'b97fe970-1ae4-4429-86d6-68e767ab1500',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.689828Z'},
#   {'trade_id': '407eea36-8744-407a-bdd9-6fd10a3224e9',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.679531Z'},
#   {'trade_id': '9480fcaf-81fa-473d-a107-b68d05ea29ae',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.669654Z'},
#   {'trade_id': '6f4afd31-802d-490a-b64a-4c9fb1a9e7b8',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.653306Z'},
#   {'trade_id': '1e09a017-82ed-4618-9749-b14d8a5db797',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T21:24:31.639444Z'},
#   {'trade_id': '81468ac7-a779-4898-91b8-99354bb5d45c',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:25.035275Z'},
#   {'trade_id': '96aea34c-f0d7-4afe-ac0f-7c87c1a87708',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:25.026432Z'},
#   {'trade_id': '924cc00f-a821-48ce-b135-e407300004a5',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:25.012495Z'},
#   {'trade_id': '727d6b81-4748-4155-bacf-85718016e910',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:25.00171Z'},
#   {'trade_id': '1cb7b546-5bb2-4666-b6b1-bdd238541bc4',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.992114Z'},
#   {'trade_id': '9e6dc851-c5c1-445e-8bd0-40c00d863ced',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.980487Z'},
#   {'trade_id': 'cf0aa846-4c63-4e7b-93e2-f525967c6f62',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.970687Z'},
#   {'trade_id': 'c9adb0b9-5f31-4ca4-9269-422c5df9c4c6',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.96081Z'},
#   {'trade_id': '18041630-bff9-4694-a74e-6f524bc3c833',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.950848Z'},
#   {'trade_id': 'e4131f44-a406-4d25-8210-5cf6b1bf32a8',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.940795Z'},
#   {'trade_id': '908d4eba-2eb3-4982-a286-48628d1fc31a',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.932628Z'},
#   {'trade_id': '1b5eccc1-f110-4510-ae87-91a5f69a7e51',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T19:28:24.92026Z'},
#   {'trade_id': '5bc7dc59-6f9f-4457-ba80-4153b8ef9e19',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.149617Z'},
#   {'trade_id': '619aa251-829a-4093-9992-56c8f5299178',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.134568Z'},
#   {'trade_id': '4f02555e-7308-4ead-ad45-fae0eb4c8753',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.123387Z'},
#   {'trade_id': 'f7c00aca-85b0-4e6f-8c4c-e2c193e4186b',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.113312Z'},
#   {'trade_id': '399dc86f-6368-41bb-9ff4-e157acb84da2',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.104226Z'},
#   {'trade_id': '387932a8-16f8-46ff-9e70-19b1b89cde5a',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.087721Z'},
#   {'trade_id': '056d661c-0e2e-4a1b-9fcb-19e7ec2224a4',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.081392Z'},
#   {'trade_id': 'a52dabb1-2de0-483e-b019-ed25fd422f01',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.068817Z'},
#   {'trade_id': '6026844a-ff7a-4282-bb70-a99f25acca88',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.060787Z'},
#   {'trade_id': '0a61c92a-784e-46dd-93b3-fc637fa5d9e1',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.049153Z'},
#   {'trade_id': 'b3b3e3c5-bca3-4444-981d-ce25a9ce8c05',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T17:20:34.041227Z'},
#   {'trade_id': '207e2161-f2c7-43e7-9dcb-961ae37fe4d1',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.647794Z'},
#   {'trade_id': 'd974ab0b-be17-4b4c-80f4-333e38401f06',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.640518Z'},
#   {'trade_id': '022982d6-a333-4353-a780-1ac78641fa26',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.629795Z'},
#   {'trade_id': '3611f1ef-36f8-4c3c-ad82-6d1544770500',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.617722Z'},
#   {'trade_id': '487cdc15-4207-42e3-abfa-7215833c8187',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.608198Z'},
#   {'trade_id': '19b6e67f-967b-495b-b341-857109180f31',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.593519Z'},
#   {'trade_id': '464e5054-969d-4732-872f-ad4486880617',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.584792Z'},
#   {'trade_id': '5ad07391-5297-4f5b-9fff-c1cbabec95dd',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.573408Z'},
#   {'trade_id': 'f758cce9-9f77-4095-89e7-a7154bdc0620',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.565696Z'},
#   {'trade_id': 'c6208801-9040-4835-8138-7471b9814ab5',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.553768Z'},
#   {'trade_id': '053a3fc2-9ba5-4918-a21b-ba6023034430',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T14:52:39.545509Z'},
#   {'trade_id': '24b3ad5d-6025-42df-a085-e235278b18a0',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.821661Z'},
#   {'trade_id': '98e28d76-f659-4a3b-9a57-daf4ab79f2d5',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.812239Z'},
#   {'trade_id': '56bbf967-6648-48f1-b583-8dd4d87e66cb',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.803807Z'},
#   {'trade_id': 'f24055d3-7a71-4f74-9cad-8a272c71fdf8',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.793098Z'},
#   {'trade_id': 'e7540f24-d8c7-422d-8ae6-f5075947b25f',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.778256Z'},
#   {'trade_id': '0cb04ae8-18db-482f-a009-62844a978d84',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.769849Z'},
#   {'trade_id': 'fc59a139-77b7-4dd1-b692-3af76207eea7',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.75899Z'},
#   {'trade_id': 'c1276011-de6a-4430-afac-5e4be0569feb',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.749662Z'},
#   {'trade_id': '3abba717-b7f0-40b3-ab03-c6bfbf379cfe',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.741762Z'},
#   {'trade_id': '9ad3c37c-643d-4b01-88ec-ab55430ab689',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.73601Z'},
#   {'trade_id': '51802dd7-c538-4662-b2ce-a403c258de89',
#    'ticker': 'TOPALBUMYEAR-24-TTPD',
#    'order_id': '33174880-7e05-490f-9d34-aef75fa87488',
#    'side': 'no',
#    'action': 'buy',
#    'count': 1,
#    'yes_price': 50,
#    'no_price': 50,
#    'is_taker': False,
#    'created_time': '2024-04-25T12:18:18.722484Z'}],
#  'cursor': 'EhIKEFGALdfFOEZiss6kA8JY3okaDAiKlKmxBhCg9sDYAg'}

# %%
# you may even want to check on some of your recent positions settled...

settlement_params = {'limit': None,
                        'cursor': None}

settlements = exchange_client.get_portfolio_settlements(**settlement_params)
settlements
# Out:
# {'settlements': []}

# %%
# Now onto placing an order...
# There are many different ways to think about placing orders at Kalshi. 
# The following param examples will walk through some of those

# Limit buy order for 10 units at 30c No on GDPW-22-A3

ticker = 'TESTING-5'

order_params = {'ticker':ticker,
                    'client_order_id':str(uuid.uuid4()),
                    'type':'limit',
                    'action':'buy',
                    'side':'no',
                    'count':10,
                    'yes_price':None, # yes_price = 100 - no_price
                    'no_price':30, # no_price = 100 - yes_price
                    'expiration_ts':None,
                    'sell_position_floor':None,
                    'buy_max_cost':None}

exchange_client.create_order(**order_params)

# EQUIVALENTLY, because buying No is equivalent to selling yes...

# order_params = {'ticker':ticker,
#                     'client_order_id':str(uuid.uuid4()),
#                     'type':'limit',
#                     'action':'sell',
#                     'side':'yes',
#                     'count':10,
#                     'yes_price':None, # yes_price = 100 - no_price
#                     'no_price':30, # no_price = 100 - yes_price
#                     'expiration_ts':None,
#                     'sell_position_floor':None,
#                     'buy_max_cost':None}

# exchange_client.create_order(**order_params)


# # Market sell order for 12 units Yes on GDPW-22-A3, without flipping position

# order_params = {'ticker':ticker,
#                     'client_order_id':str(uuid.uuid4()),
#                     'type':'market',
#                     'action':'sell',
#                     'side':'yes',
#                     'count':12,
#                     'yes_price':1,
#                     'no_price':None,
#                     'expiration_ts':None,
#                     'sell_position_floor':0,
#                     'buy_max_cost':None}

# exchange_client.create_order(**order_params)

# # EQUIVALENTLY, because buying No is equivalent to selling yes...

# order_params = {'ticker':ticker,
#                     'client_order_id':str(uuid.uuid4()),
#                     'type':'market',
#                     'action':'buy',
#                     'side':'no',
#                     'count':12,
#                     'yes_price':1,
#                     'no_price':None,
#                     'expiration_ts':None,
#                     'sell_position_floor':0,
#                     'buy_max_cost':None}

# exchange_client.create_order(**order_params)
# Out:
# {'ticker': 'TESTING-5', 'client_order_id': 'bfbd2cb1-2a37-454a-9276-4700ba64f084', 'side': 'no', 'action': 'buy', 'count': 10, 'type': 'limit', 'no_price': 30}
# msg_string 1724881878733POST/trade-api/v2/portfolio/orders
# signature 
# {'order': {'order_id': 'a83b4604-6ad5-49e0-bf65-d89b175df537',
#   'user_id': 'd6a190b7-31de-4855-9fed-e1fd364dc2cf',
#   'ticker': 'TESTING-5',
#   'status': 'resting',
#   'yes_price': 70,
#   'no_price': 30,
#   'created_time': '2024-08-28T21:51:18.993589Z',
#   'expiration_time': None,
#   'self_trade_prevention_type': '',
#   'action': 'buy',
#   'side': 'no',
#   'type': 'limit',
#   'client_order_id': 'bfbd2cb1-2a37-454a-9276-4700ba64f084',
#   'order_group_id': ''}}
